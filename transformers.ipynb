# %% [markdown]
# <a href="https://colab.research.google.com/github/aryan151pratap/Generative-AI-and-LLMs/blob/main/transformers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2026.1.4)

# %%
from transformers import pipeline
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work

# %%
model = pipeline("summarization", "sshleifer/distilbart-cnn-12-6")
# Out:
# Device set to use cpu

# %%
text = '''
BERT (Bidirectional Encoder Representations from Transformers) is a recent paper published by researchers at Google AI Language.
It has caused a stir in the Machine Learning community by presenting state-of-the-art results in a wide variety of NLP tasks, including Question Answering (SQuAD v1.1), Natural Language Inference (MNLI), and others.

BERT’s key technical innovation is applying the bidirectional training of Transformer, a popular attention model, to language modelling.
This is in contrast to previous efforts which looked at a text sequence either from left to right or combined left-to-right and right-to-left training.
The paper’s results show that a language model which is bidirectionally trained can have a deeper sense of language context and flow than single-direction language models. In the paper, the researchers detail a novel technique named Masked LM (MLM) which allows bidirectional training in models in which it was previously impossible.
'''

# %%
ans = model(text, max_new_tokens=100)

# %%
ans
# Out:
# [{'summary_text': ' Bidirectional Encoder Representations from Transformers (BERT) is a recent paper published by Google AI Language.BERT’s key technical innovation is applying the bidirectional training of Transformer, a popular attention model, to language modelling. This is in contrast to previous efforts which looked at a text sequence either from left to right or combined left-to-right and right-to the left training.'}]

# %%
result = ans[0]['summary_text'].split(".")

# %%
for i in result:
  if len(i.split()) > 5:
    print(i+".")
# Out:
#  Bidirectional Encoder Representations from Transformers (BERT) is a recent paper published by Google AI Language.
# BERT’s key technical innovation is applying the bidirectional training of Transformer, a popular attention model, to language modelling.
#  This is in contrast to previous efforts which looked at a text sequence either from left to right or combined left-to-right and right-to the left training.

# %%
# read a document and make a summary of 50 words. and give same summary document.

# %%
# 3 application of generative AI (Question/ Answering)

# %%
model = pipeline("question-answering")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 564e9b5 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/473 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/261M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Device set to use cpu

# %%
context = '''
A computer is an electronic machine that is used to store, process, and manage data. It works according to the instructions given by the user. Computers help us perform calculations, create documents, browse the internet, and communicate with others. They are widely used in education, business, healthcare, and entertainment. With the help of computers, work becomes faster, easier, and more accurate.
'''

# %%
result = model(question="what is computer", context=context)

# %%
result
# Out:
# {'score': 0.33598658442497253,
#  'start': 15,
#  'end': 84,
#  'answer': 'an electronic machine that is used to store, process, and manage data'}

# %%
while True:
  text = input("question: ")
  if text == "exit":
    break
  if text.split(":")[0] == "context":
    context = text
    print("\nresponse: ", "context change to -\n", text, "\n\n")
    continue
  result = model(question=text, context=context)
  print("answer: ", result['answer'])
# Out:
# question: exit

# %%
# 4. application of generative AI (translation (language translation))  work on parellel corpus

# %%
translator = pipeline("translation_en_to_fr")
# Out:
# No model was supplied, defaulted to google-t5/t5-base and revision a9723ea (https://huggingface.co/google-t5/t5-base).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/892M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Device set to use cpu

# %%
p = "whats your name"
result = translator(p)

# %%
result
# Out:
# [{'translation_text': 'quel est votre nom?'}]

# %%
translator2 = pipeline("translation", model="Helsinki-NLP/opus-mt-fr-en")
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/301M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/802k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/778k [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# /usr/local/lib/python3.12/dist-packages/transformers/models/marian/tokenization_marian.py:175: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# Device set to use cpu

# %%
eng = translator2(result[0]['translation_text'])

# %%
eng
# Out:
# [{'translation_text': "What's your name?"}]

# %% [markdown]
# PDF text summarization into a single page PDF

# %%
# !pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 5.3 MB/s eta 0:00:00
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1

# %%
from PyPDF2 import PdfReader

reader = PdfReader("Generative_AI_and_LLMs_Full.pdf")

text_data = []
for page in reader.pages:
    text_data.append(page.extract_text())

print(text_data)
# Out:
# ['Generative Artificial Intelligence\nGenerative Artificial Intelligence (Generative AI) is a branch of artificial intelligence that focuses on\ncreating systems capable of generating new and original content. This content can include text,\nimages, audio, video, code, and synthetic data. Unlike traditional AI systems that are designed only\nto classify, predict, or recognize patterns, generative AI models learn the underlying distribution of\nthe training data and use this knowledge to generate outputs that closely resemble real-world data.\nGenerative AI works by training deep learning models on large datasets so that they can\nunderstand patterns, structures, and relationships within the data. Once trained, these models can\ngenerate new data instances that are not exact copies of the training data but are statistically\nsimilar. This ability makes generative AI extremely powerful and flexible.\nApplications of generative AI include chatbots, virtual assistants, automated content writing, image\ngeneration, music composition, video creation, data augmentation for machine learning, and\nsoftware development. Popular generative models include Generative Adversarial Networks\n(GANs), Variational Autoencoders (VAEs), Diffusion Models, and Transformer-based architectures.\nThe rapid development of generative AI has been made possible by three major factors: availability\nof large-scale datasets, advancements in GPU and TPU hardware, and improvements in deep\nlearning algorithms. However, generative AI also raises challenges such as bias, misinformation,\ncopyright concerns, and ethical issues, which must be addressed responsibly.\n', 'Large Language Models (LLMs)\nLarge Language Models (LLMs) are a specialized category of generative AI models designed to\nunderstand, process, and generate human language. They are trained on massive amounts of text\ndata collected from books, articles, websites, and other textual sources. Through this training, LLMs\nlearn grammar, syntax, semantics, and contextual relationships between words.\nLLMs are built using deep neural networks with a very large number of parameters, often ranging\nfrom millions to hundreds of billions. The size of these models allows them to capture complex\nlinguistic patterns and perform a wide variety of natural language processing tasks. These tasks\ninclude text generation, translation, summarization, question answering, sentiment analysis, code\ngeneration, and conversational AI.\nExamples of well-known LLMs include GPT (Generative Pre-trained Transformer), BERT\n(Bidirectional Encoder Representations from Transformers), T5 (Text-to-Text Transfer\nTransformer), PaLM, and LLaMA. Each of these models is designed with a specific architecture and\npurpose in mind.\nDespite their impressive capabilities, LLMs have limitations such as high computational cost,\ndependency on training data quality, and the possibility of generating incorrect or misleading\ninformation. Therefore, careful fine-tuning, evaluation, and responsible deployment are essential.\n', 'Encoder and Decoder Architecture\nThe encoder-decoder architecture is a fundamental design used in modern deep learning models,\nespecially in natural language processing. It is widely used in tasks such as machine translation,\ntext summarization, and speech recognition. This architecture consists of two main components: an\nencoder and a decoder.\nEncoder:\nThe encoder takes the input sequence (such as a sentence) and converts it into a fixed-length or\nsequence-based numerical representation called embeddings. It captures contextual and semantic\ninformation from the input by processing all tokens together. In transformer-based models, the\nencoder uses self-attention mechanisms to understand relationships between words regardless of\ntheir position.\nDecoder:\nThe decoder generates the output sequence based on the encoded representation provided by the\nencoder. It produces the output token by token while consideri ...

# %%
summary = pipeline("summarization")
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu

# %%
summary_result = []

for i in text_data:
  print(i)
  ans = summary(i, max_new_tokens=100)
  summary_result.append(ans)
# Out:
# Generative Artificial Intelligence
# Generative Artificial Intelligence (Generative AI) is a branch of artificial intelligence that focuses on
# creating systems capable of generating new and original content. This content can include text,
# images, audio, video, code, and synthetic data. Unlike traditional AI systems that are designed only
# to classify, predict, or recognize patterns, generative AI models learn the underlying distribution of
# the training data and use this knowledge to generate outputs that closely resemble real-world data.
# Generative AI works by training deep learning models on large datasets so that they can
# understand patterns, structures, and relationships within the data. Once trained, these models can
# generate new data instances that are not exact copies of the training data but are statistically
# similar. This ability makes generative AI extremely powerful and flexible.
# Applications of generative AI include chatbots, virtual assistants, automated content writing, image
# generation, music composition, video creation, data augmentation for machine learning, and
# software development. Popular generative models include Generative Adversarial Networks
# (GANs), Variational Autoencoders (VAEs), Diffusion Models, and Transformer-based architectures.
# The rapid development of generative AI has been made possible by three major factors: availability
# of large-scale datasets, advancements in GPU and TPU hardware, and improvements in deep
# learning algorithms. However, generative AI also raises challenges such as bias, misinformation,
# copyright concerns, and ethical issues, which must be addressed responsibly.
#
# Large Language Models (LLMs)
# Large Language Models (LLMs) are a specialized category of generative AI models designed to
# understand, process, and generate human language. They are trained on massive amounts of text
# data collected from books, articles, websites, and other textual sources. Through this training, LLMs
# learn grammar, syntax, semantics, and contextual relationships between words.
# LLMs are built using deep neural networks with a very large number of parameters, often ranging
# from millions to hundreds of billions. The size of these models allows them to capture complex
# linguistic patterns and perform a wide variety of natural language processing tasks. These tasks
# include text generation, translation, summarization, question answering, sentiment analysis, code
# generation, and conversational AI.
# Examples of well-known LLMs include GPT (Generative Pre-trained Transformer), BERT
# (Bidirectional Encoder Representations from Transformers), T5 (Text-to-Text Transfer
# Transformer), PaLM, and LLaMA. Each of these models is designed with a specific architecture and
# purpose in mind.
# Despite their impressive capabilities, LLMs have limitations such as high computational cost,
# dependency on training data quality, and the possibility of generating incorrect or misleading
# information. Therefore, careful fine-tuning, evaluation, and responsible deployment are essential.
#
# Encoder and Decoder Architecture
# The encoder-decoder architecture is a fundamental design used in modern deep learning models,
# especially in natural language processing. It is widely used in tasks such as machine translation,
# text summarization, and speech recognition. This architecture consists of two main components: an
# encoder and a decoder.
# Encoder:
# The encoder takes the input sequence (such as a sentence) and converts it into a fixed-length or
# sequence-based numerical representation called embeddings. It captures contextual and semantic
# information from the input by processing all tokens together. In transformer-based models, the
# encoder uses self-attention mechanisms to understand relationships between words regardless of
# their position.
# Decoder:
# The decoder generates the output sequence based on the encoded representation provided by the
# encoder. It produces the output token by token while considering both the encoded input and
# previously generated tokens. The decoder uses masked self-attention and encoder-decoder
# attention to ensure meaningful and coherent output generation.
# This separation of understanding (encoder) and generation (decoder) makes the architecture
# powerful and flexible for many sequence-to-sequence tasks.
#
# Types of LLM Architectures
# Based on the use of encoders and decoders, Large Language Models can be classified into three
# main types. Each type is optimized for specific tasks and applications.
# 1. Encoder-only Models:
# Encoder-only models focus on understanding input text rather than generating new text. They are
# bidirectional, meaning they consider both left and right context simultaneously. These models are
# commonly used for tasks such as text classification, sentiment analysis, and named entity
# recognition. Example: BERT.
# 2. Decoder-only Models:
# Decoder-only models are designed primarily for text generation. They generate text sequentially
# and rely on previous tokens to predict the next token. These models are well-suited for chatbots,
# story generation, and code generation. Example: GPT.
# 3. Encoder-Decoder Models:
# Encoder-decoder models combine both components and are mainly used for
# sequence-to-sequence tasks. They are widely used in machine translation, summarization, and
# question answering. Example: T5.
# In conclusion, the choice of architecture depends on the task requirements, computational
# resources, and desired output quality. Understanding these architectures is essential for effectively
# using generative AI and LLMs.

# %%
summary_result
# Out:
# [[{'summary_text': ' Generative Artificial Intelligence (Generative AI) is a branch of artificial intelligence that focuses on creating systems capable of generating new and original content . Unlike traditional AI systems that are designed only to classify, predict, or recognize patterns, generative AI models learn the underlying distribution of the training data and use this knowledge to generate outputs that closely resemble real-world data . Popular generative models include Generative Adversarial Networks and Variational Autoencoders .'}],
#  [{'summary_text': ' Large Language Models (LLMs) are a specialized category of generative AI models designed to understand, process, and generate human language . They are trained on massive amounts of text data collected from books, articles, websites, and other textual sources . LLMs are built using deep neural networks with a large number of parameters, often ranging from millions to hundreds of billions .'}],
#  [{'summary_text': ' The encoder-decoder architecture is a fundamental design used in modern deep learning models . It is widely used in tasks such as machine translation, text summarization, and speech recognition . The architecture consists of two main components: an encoder and a decoder . It captures contextual and semantic information from the input by processing all tokens together .'}],
#  [{'summary_text': ' Large Language Models can be classified into three main types . Each type is optimized for specific tasks and applications . Understanding these architectures is essential for effectively using generative AI and LLMs . The choice of architecture depends on the task requirements, computational resources, and desired output quality .'}]]

# %%
# !pip install fpdf
# Out:
# Collecting fpdf
#   Downloading fpdf-1.7.2.tar.gz (39 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: fpdf
#   Building wheel for fpdf (setup.py) ... done
#   Created wheel for fpdf: filename=fpdf-1.7.2-py2.py3-none-any.whl size=40704 sha256=3315da94c01fc5a25e5f4b2246c04667971e0ff0a7eb6956084f3bdae72a973a
#   Stored in directory: /root/.cache/pip/wheels/6e/62/11/dc73d78e40a218ad52e7451f30166e94491be013a7850b5d75
# Successfully built fpdf
# Installing collected packages: fpdf
# Successfully installed fpdf-1.7.2

# %%
pdf_text = ""
for i in summary_result:
  pdf_text += i[0]['summary_text'] + "\n"

# %%
pdf_text
# Out:
# ' Generative Artificial Intelligence (Generative AI) is a branch of artificial intelligence that focuses on creating systems capable of generating new and original content . Unlike traditional AI systems that are designed only to classify, predict, or recognize patterns, generative AI models learn the underlying distribution of the training data and use this knowledge to generate outputs that closely resemble real-world data . Popular generative models include Generative Adversarial Networks and Variational Autoencoders .\n Large Language Models (LLMs) are a specialized category of generative AI models designed to understand, process, and generate human language . They are trained on massive amounts of text data collected from books, articles, websites, and other textual sources . LLMs are built using deep neural networks with a large number of parameters, often ranging from millions to hundreds of billions .\n The encoder-decoder architecture is a fundamental design used in modern deep learning models . It is widely used in tasks such as machine translation, text summarization, and speech recognition . The architecture consists of two main components: an encoder and a decoder . It captures contextual and semantic information from the input by processing all tokens together .\n Large Language Models can be classified into three main types . Each type is optimized for specific tasks and applications . Understanding these architectures is essential for effectively using generative AI and LLMs . The choice of architecture depends on the task requirements, computational resources, and desired output quality .\n'

# %%
from fpdf import FPDF

pdf = FPDF()
pdf.add_page()
pdf.set_font("Arial", size=12)

pdf.multi_cell(0, 8, pdf_text)

pdf.output("output.pdf")
# Out:
# ''
